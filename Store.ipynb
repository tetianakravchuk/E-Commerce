# %%
import pandas as pd

orders = pd.read_csv('orders.csv')

products = pd.read_csv('products.csv')

customers = pd.read_csv('customers.csv')
print(orders)
print(products)
print(customers)
# Out:
#     order_id  customer_id product_id  quantity     timestamp
# 0          1          122       1051         5  1/17/24 1:24
# 1          2          123       1064       555  9/12/23 1:24
# 2          3          124      1092          3  2/12/24 1:24
# 3          4          125       1077         5  1/17/24 1:24
# 4          5          126       1090         6  9/12/23 1:24
# 5          6          127      1092          4  2/12/24 1:24
# 6          7          128       1103         7  1/17/24 1:24
# 7          8          129       1116       344  9/12/23 1:24
# 8          9          130      1092          5  2/12/24 1:24
# 9         10          131       1129       123  1/17/24 1:24
# 10        11          132       1142       535  9/12/23 1:24
# 11        12          133      1092       1124  2/12/24 1:24
# 12        13          134       1155       235  1/17/24 1:24
# 13        14          135       1168      4345  9/12/23 1:24
# ...
